# %%
import numpy as np
import matplotlib.pyplot as plt
import yaml
import main_functions as mf

# %%
input_file = "inputs.yaml"
mf.display_inputs(input_file)

# %%
mf.main_simulation(input_file)

# %%
mf.visualize(input_file)

# %%
mf.transfer_function(input_file)
